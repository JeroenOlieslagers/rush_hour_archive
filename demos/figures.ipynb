# %%
cd("..")
include("../src/load_scripts.jl")
# Out:
# get_subjs_prbs (generic function with 1 method)

# %% [markdown]
# The code below loads all the data and model parameters, it might take up to a minute to run if you have all of the processed data available.
#
# If the processed data is not available, it will take considerably longer.

# %%
df, messy_data, d_goals_prbs, df_models, df_stats, binned_stats = load_processed_data();
subjs, prbs = get_subjs_prbs(df);
# Out:
# Loading raw data...
# Rejection ratio: 52/94
# Loading distance to goal...
# Loading AND-OR trees...
# Loading MC matrices...
# Loading models...
# Loading summary stats...
# Loading binned stats...

# %%
fig2D(df, prbs)

# %%
fig4(df_models)

# %%
fig5(binned_stats)

# %%
fig6(df_stats)

# %%
fig7(binned_stats)

# %%
supplement_fig2(df, messy_data)
# Out:
# ArgumentError: syntax df[column] is not supported use df[!, column] instead
#
#
#
# Stacktrace:
#
#  [1] getindex(#unused#::DataFrame, #unused#::String)
#
#    @ DataFrames ~/.julia/packages/DataFrames/58MUJ/src/abstractdataframe/abstractdataframe.jl:2480
#
#  [2] add_completion_data!(opt_df::DataFrame, messy_data::DataFrame, prbs::Vector{String})
#
#    @ Main ~/Documents/PhD projects/rush_hour/src/data_analysis.jl:48
#
#  [3] supplement_fig2(df::DataFrame, messy_data::DataFrame)
#
#    @ Main ~/Documents/PhD projects/rush_hour/src/plotting.jl:232
#
#  [4] top-level scope
#
#    @ ~/Documents/PhD projects/rush_hour/demos/figures.ipynb:1

# %%
supplement_fig4(df)

# %%
supplement_fig5(df, d_goals_prbs)
# Out:
# UndefVarError: d_goals_prbs not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/PhD projects/rush_hour/demos/figures.ipynb:1

# %%
supplement_fig6(df)

# %%
supplement_fig7(df)

# %%
supplement_fig8(df)
